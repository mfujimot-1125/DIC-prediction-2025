# %%
import os
import pandas as pd
import h2o
from h2o.automl import H2OAutoML

# %%
date = "20250420"
data_dir = '../data/'
output_dir = '../output/'
featureset = 'featureset.csv'

# %% [markdown]
# ### Run H2O AutoML

# %%
h2o.init(max_mem_size="8G")
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# Attempting to start a local H2O server...
#   Java Version: java version "1.8.0_451"; Java(TM) SE Runtime Environment (build 1.8.0_451-b10); Java HotSpot(TM) 64-Bit Server VM (build 25.451-b10, mixed mode)
#   Starting server from /Users/fujimoto/Desktop/MedICU/research-dic-prediction-2025/scripts/myenv/lib/python3.13/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/mw/7366jqyd24db0gsndhcd1cl00000gn/T/tmpkgfozy7z
#   JVM stdout: /var/folders/mw/7366jqyd24db0gsndhcd1cl00000gn/T/tmpkgfozy7z/h2o_fujimoto_started_from_python.out
#   JVM stderr: /var/folders/mw/7366jqyd24db0gsndhcd1cl00000gn/T/tmpkgfozy7z/h2o_fujimoto_started_from_python.err
#   Server is running at http://127.0.0.1:54345
# Connecting to H2O server at http://127.0.0.1:54345 ... successful.
# --------------------------  -------------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       Asia/Tokyo
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.7
# H2O_cluster_version_age:    25 days
# H2O_cluster_name:           H2O_from_python_fujimoto_pp3ux7
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.097 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54345
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.13.3 final
# --------------------------  -------------------------------

# %%
def get_aml_model(train_path: str, 
                  test_path:str, 
                vars: list, random_seed: int) -> None:
    train = h2o.import_file(os.path.join(data_dir, date, train_path))
    train = train[vars]
    test = h2o.import_file(os.path.join(data_dir, date, test_path)) 
    test = test[vars]

    x = train.columns
    y = 'y'
    x.remove(y)
    train[y] = train[y].asfactor()
    test[y] = test[y].asfactor()
    aml = H2OAutoML(max_models=20, seed=random_seed, exclude_algos=["StackedEnsemble"], verbosity = "debug")
    aml.train(x=x, y=y, training_frame=train)

    return aml, train, test

# %%
#retrieve the features from the featureset for each model
df = pd.read_csv(os.path.join(data_dir,featureset))
minimum_model_features = df[df['minimum model'] == 1]['Feature'].tolist()
compact_model_features = df[df['compact model'] == 1]['Feature'].tolist()
full_model_features = df[df['full model'] == 1]['Feature'].tolist()

# %%
vars_full = full_model_features+['y']
vars_minimum = minimum_model_features + ['y']
vars_compact = compact_model_features + ['y']

# %% [markdown]
# #### Run H2O AutoML for full model

# %%
aml_DIC, train, test = get_aml_model(f'{date}_train_df_model1.csv', f"{date}_test_df_model1.csv", vars_full, 780)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 19:20:35.13: Project: AutoML_1_20250421_192034
# 19:20:35.15: 5-fold cross-validation will be used.
# 19:20:35.30: Setting stopping tolerance adaptively based on the training frame: 0.006505725117543193
# 19:20:35.30: Build control seed: 780
# 19:20:35.32: training frame: Frame key: AutoML_1_20250421_192034_training_py_47_sid_8209    cols: 64    rows: 23627  chunks: 32    size: 3465522  checksum: 4604309751270896018
# 19:20:35.32: validation frame: NULL
# 19:20:35.32: leaderboard frame: NULL
# 19:20:35.32: blending frame: NULL
# 19:20:35.32: response column: y
# 19:20:35.32: fold column: null
# 19:20:35.32: weights column: null
# 19:20:35.51: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (7g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (7g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (6g, 60w)]}, {StackedEnsemble : [monotonic (9g, 10w), best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 19:20:35.75: Disabling Algo: StackedEnsemble as requested by the user.
# 19:20:35.75: Defined work allocations: [Work{def_2, XGBoost, ModelBuild, group=1, weight=10}, Work{def_1, GLM, ModelBuild, group=1, weight=10}, Work{def_5, GBM, ModelBuild, group=1, weight=10}, Work{def_1, XGBoost, ModelBuild, group=2, weight=10}, Work{def_1, DRF, ModelBuild, group=2, weight=10}, Work{def_2, GBM, ModelBuild, group=2, weight=10}, Work{def_3, GBM, ModelBuild, group=2, weight=10}, Work{def_4, GBM, ModelBuild, group=2, weight=10}, Work{def_3, XGBoost, ModelBuild, group=3, weight=10}, Work{XRT, DRF, ModelBuild, group=3, weight=10}, Work{def_1, GBM, ModelBuild, group=3, weight=10}, Work{def_1, DeepLearning, ModelBuild, group=3, weight=10}, Work{grid_1, XGBoost, HyperparamSearch, group=4, weight=90}, Work{grid_1, GBM, HyperparamSearch, group=4, weight=60}, Work{grid_1, DeepLearning, HyperparamSearch, group=4, weight=30}, Work{grid_2, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{grid_3, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{resume_best_grids, virtual, Dynamic, group=6, weight=60}, Work{lr_search, XGBoost, Selection, group=7, weight=30}, Work{lr_annealing, GBM, Selection, group=7, weight=10}]
# 19:20:35.75: Actual work allocations: [Work{def_2, XGBoost, ModelBuild, group=1, weight=10}, Work{def_1, GLM, ModelBuild, group=1, weight=10}, Work{def_5, GBM, ModelBuild, group=1, weight=10}, Work{def_1, XGBoost, ModelBuild, group=2, weight=10}, Work{def_1, DRF, ModelBuild, group=2, weight=10}, Work{def_2, GBM, ModelBuild, group=2, weight=10}, Work{def_3, GBM, ModelBuild, group=2, weight=10}, Work{def_4, GBM, ModelBuild, group=2, weight=10}, Work{def_3, XGBoost, ModelBuild, group=3, weight=10}, Work{XRT, DRF, ModelBuild, group=3, weight=10}, Work{def_1, GBM, ModelBuild, group=3, weight=10}, Work{def_1, DeepLearning, ModelBuild, group=3, weight=10}, Work{grid_1, XGBoost, HyperparamSearch, group=4, weight=90}, Work{grid_1, GBM, HyperparamSearch, group=4, weight=60}, Work{grid_1, DeepLearning, HyperparamSearch, group=4, weight=30}, Work{grid_2, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{grid_3, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{resume_best_grids, virtual, Dynamic, group=6, weight=60}, Work{lr_search, XGBoost, Selection, group=7, weight=30}, Work{lr_annealing, GBM, Selection, group=7, weight=10}]
# 19:20:35.75: AutoML job created: 2025.04.21 19:20:34.984
# 19:20:35.80: AutoML build started: 2025.04.21 19:20:35.76
# 19:20:35.107: No time limitation for XGBoost_1_AutoML_1_20250421_192034
# 19:20:35.109: AutoML: starting XGBoost_1_AutoML_1_20250421_192034 model training
# 19:20:35.119: XGBoost_1_AutoML_1_20250421_192034 [XGBoost def_2] started
#
# ██
# 19:20:54.962: XGBoost_1_AutoML_1_20250421_192034 [XGBoost def_2] complete
# 19:20:54.966: Adding model XGBoost_1_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=5s, total=20s
# 19:20:54.995: New leader: XGBoost_1_AutoML_1_20250421_192034, auc: 0.9165731743536673
# 19:20:55.0: No time limitation for GLM_1_AutoML_1_20250421_192034
# 19:20:55.1: AutoML: starting GLM_1_AutoML_1_20250421_192034 model training
# 19:20:55.1: GLM_1_AutoML_1_20250421_192034 [GLM def_1] started
#
# ██
# 19:21:04.806: GLM_1_AutoML_1_20250421_192034 [GLM def_1] complete
# 19:21:04.807: Adding model GLM_1_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=1s, total=10s
# 19:21:04.823: No time limitation for GBM_1_AutoML_1_20250421_192034
# 19:21:04.823: AutoML: starting GBM_1_AutoML_1_20250421_192034 model training
# 19:21:04.836: GBM_1_AutoML_1_20250421_192034 [GBM def_5] started
#
# █
# 19:21:20.843: GBM_1_AutoML_1_20250421_192034 [GBM def_5] complete
# 19:21:20.844: Adding model GBM_1_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=2s, total=16s
# 19:21:20.849: New leader: GBM_1_AutoML_1_20250421_192034, auc: 0.9221090327391657
# 19:21:20.859: No time limitation for XGBoost_2_AutoML_1_20250421_192034
# 19:21:20.859: AutoML: starting XGBoost_2_AutoML_1_20250421_192034 model training
# 19:21:20.864: XGBoost_2_AutoML_1_20250421_192034 [XGBoost def_1] started
#
# █
# 19:21:39.796: XGBoost_2_AutoML_1_20250421_192034 [XGBoost def_1] complete
# 19:21:39.797: Adding model XGBoost_2_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=5s, total=19s
# 19:21:39.837: No time limitation for DRF_1_AutoML_1_20250421_192034
# 19:21:39.838: AutoML: starting DRF_1_AutoML_1_20250421_192034 model training
# 19:21:39.841: DRF_1_AutoML_1_20250421_192034 [DRF def_1] started
#
# ███
# 19:21:55.468: DRF_1_AutoML_1_20250421_192034 [DRF def_1] complete
# 19:21:55.469: Adding model DRF_1_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=4s, total=16s
# 19:21:55.489: No time limitation for GBM_2_AutoML_1_20250421_192034
# 19:21:55.490: AutoML: starting GBM_2_AutoML_1_20250421_192034 model training
# 19:21:55.492: GBM_2_AutoML_1_20250421_192034 [GBM def_2] started
#
# █
# 19:22:08.24: GBM_2_AutoML_1_20250421_192034 [GBM def_2] complete
# 19:22:08.25: Adding model GBM_2_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=3s, total=13s
# 19:22:08.54: No time limitation for GBM_3_AutoML_1_20250421_192034
# 19:22:08.55: AutoML: starting GBM_3_AutoML_1_20250421_192034 model training
# 19:22:08.61: GBM_3_AutoML_1_20250421_192034 [GBM def_3] started
#
# █
# 19:22:19.23: GBM_3_AutoML_1_20250421_192034 [GBM def_3] complete
# 19:22:19.23: Adding model GBM_3_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=1s, total=11s
# 19:22:19.36: No time limitation for GBM_4_AutoML_1_20250421_192034
# 19:22:19.36: AutoML: starting GBM_4_AutoML_1_20250421_192034 model training
# 19:22:19.37: GBM_4_AutoML_1_20250421_192034 [GBM def_4] started
#
# █
# 19:22:27.363: GBM_4_AutoML_1_20250421_192034 [GBM def_4] complete
# 19:22:27.364: Adding model GBM_4_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=1s, total=8s
# 19:22:27.381: No time limitation for XGBoost_3_AutoML_1_20250421_192034
# 19:22:27.381: AutoML: starting XGBoost_3_AutoML_1_20250421_192034 model training
# 19:22:27.385: XGBoost_3_AutoML_1_20250421_192034 [XGBoost def_3] started
#
# █
# 19:22:41.261: XGBoost_3_AutoML_1_20250421_192034 [XGBoost def_3] complete
# 19:22:41.261: Adding model XGBoost_3_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=3s, total=14s
# 19:22:41.274: No time limitation for XRT_1_AutoML_1_20250421_192034
# 19:22:41.275: AutoML: starting XRT_1_AutoML_1_20250421_192034 model training
# 19:22:41.276: XRT_1_AutoML_1_20250421_192034 [DRF XRT (Extremely Randomized Trees)] started
#
# ███
# 19:22:55.810: XRT_1_AutoML_1_20250421_192034 [DRF XRT (Extremely Randomized Trees)] complete
# 19:22:55.811: Adding model XRT_1_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=2s, total=15s
# 19:22:55.831: No time limitation for GBM_5_AutoML_1_20250421_192034
# 19:22:55.832: AutoML: starting GBM_5_AutoML_1_20250421_192034 model training
# 19:22:55.835: GBM_5_AutoML_1_20250421_192034 [GBM def_1] started
#
#
# 19:23:01.86: GBM_5_AutoML_1_20250421_192034 [GBM def_1] complete
# 19:23:01.87: Adding model GBM_5_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=1s, total=5s
# 19:23:01.114: No time limitation for DeepLearning_1_AutoML_1_20250421_192034
# 19:23:01.115: AutoML: starting DeepLearning_1_AutoML_1_20250421_192034 model training
# 19:23:01.118: DeepLearning_1_AutoML_1_20250421_192034 [DeepLearning def_1] started
#
# █
# 19:23:07.814: DeepLearning_1_AutoML_1_20250421_192034 [DeepLearning def_1] complete
# 19:23:07.814: Adding model DeepLearning_1_AutoML_1_20250421_192034 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=1s, total=7s
# 19:23:07.850: No time limitation for XGBoost_grid_1_AutoML_1_20250421_192034
# 19:23:07.850: AutoML: starting XGBoost_grid_1_AutoML_1_20250421_192034 hyperparameter search
# 19:23:07.910: XGBoost_grid_1_AutoML_1_20250421_192034 [XGBoost Grid Search] started
#
# ██████████
# 19:23:37.38: Built: 1 models for HyperparamSearch : XGBoost_grid_1_AutoML_1_20250421_192034 [XGBoost Grid Search]
# 19:23:37.38: Adding model XGBoost_grid_1_AutoML_1_20250421_192034_model_1 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=8s, total=29s
# 19:24:08.214: Built: 2 models for HyperparamSearch : XGBoost_grid_1_AutoML_1_20250421_192034 [XGBoost Grid Search]
# 19:24:08.214: Adding model XGBoost_grid_1_AutoML_1_20250421_192034_model_2 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=8s, total=31s
# 19:24:08.224: New leader: XGBoost_grid_1_AutoML_1_20250421_192034_model_2, auc: 0.9272666603515434
# 19:24:19.576: XGBoost_grid_1_AutoML_1_20250421_192034 [XGBoost Grid Search] complete
# 19:24:19.576: Built: 3 models for HyperparamSearch : XGBoost_grid_1_AutoML_1_20250421_192034 [XGBoost Grid Search]
# 19:24:19.576: Adding model XGBoost_grid_1_AutoML_1_20250421_192034_model_3 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=3s, total=12s
# 19:24:19.589: No time limitation for GBM_grid_1_AutoML_1_20250421_192034
# 19:24:19.589: AutoML: starting GBM_grid_1_AutoML_1_20250421_192034 hyperparameter search
# 19:24:19.590: GBM_grid_1_AutoML_1_20250421_192034 [GBM Grid Search] started
#
# █████████████
# 19:24:26.615: Built: 1 models for HyperparamSearch : GBM_grid_1_AutoML_1_20250421_192034 [GBM Grid Search]
# 19:24:26.616: Adding model GBM_grid_1_AutoML_1_20250421_192034_model_1 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=1s, total=6s
# 19:24:31.449: GBM_grid_1_AutoML_1_20250421_192034 [GBM Grid Search] complete
# 19:24:31.449: Built: 2 models for HyperparamSearch : GBM_grid_1_AutoML_1_20250421_192034 [GBM Grid Search]
# 19:24:31.450: Adding model GBM_grid_1_AutoML_1_20250421_192034_model_2 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=1s, total=6s
# 19:24:31.463: No time limitation for DeepLearning_grid_1_AutoML_1_20250421_192034
# 19:24:31.463: AutoML: starting DeepLearning_grid_1_AutoML_1_20250421_192034 hyperparameter search
# 19:24:31.468: DeepLearning_grid_1_AutoML_1_20250421_192034 [DeepLearning Grid Search] started
#
# ██████████████
# 19:27:13.16: DeepLearning_grid_1_AutoML_1_20250421_192034 [DeepLearning Grid Search] complete
# 19:27:13.16: Built: 1 models for HyperparamSearch : DeepLearning_grid_1_AutoML_1_20250421_192034 [DeepLearning Grid Search]
# 19:27:13.17: Adding model DeepLearning_grid_1_AutoML_1_20250421_192034_model_1 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=27s, total=162s
# 19:27:13.33: No time limitation for DeepLearning_grid_2_AutoML_1_20250421_192034
# 19:27:13.33: AutoML: starting DeepLearning_grid_2_AutoML_1_20250421_192034 hyperparameter search
# 19:27:13.34: DeepLearning_grid_2_AutoML_1_20250421_192034 [DeepLearning Grid Search] started
#
# ████
# 19:29:58.541: DeepLearning_grid_2_AutoML_1_20250421_192034 [DeepLearning Grid Search] complete
# 19:29:58.541: Built: 1 models for HyperparamSearch : DeepLearning_grid_2_AutoML_1_20250421_192034 [DeepLearning Grid Search]
# 19:29:58.542: Adding model DeepLearning_grid_2_AutoML_1_20250421_192034_model_1 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=31s, total=165s
# 19:29:58.576: No time limitation for DeepLearning_grid_3_AutoML_1_20250421_192034
# 19:29:58.576: AutoML: starting DeepLearning_grid_3_AutoML_1_20250421_192034 hyperparameter search
# 19:29:58.579: DeepLearning_grid_3_AutoML_1_20250421_192034 [DeepLearning Grid Search] started
#
# █████| (done) 100%
#
# 19:33:00.415: DeepLearning_grid_3_AutoML_1_20250421_192034 [DeepLearning Grid Search] complete
# 19:33:00.415: Built: 1 models for HyperparamSearch : DeepLearning_grid_3_AutoML_1_20250421_192034 [DeepLearning Grid Search]
# 19:33:00.417: Adding model DeepLearning_grid_3_AutoML_1_20250421_192034_model_1 to leaderboard Leaderboard_AutoML_1_20250421_192034@@y. Training time: model=37s, total=182s
# 19:33:00.446: AutoML: hit the max_models limit; skipping completion resume_best_grids
# 19:33:00.446: AutoML: hit the max_models limit; skipping XGBoost lr_search
# 19:33:00.446: AutoML: hit the max_models limit; skipping GBM lr_annealing
# 19:33:00.468: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option or it is already trained.
# 19:33:00.470: Skipping StackedEnsemble 'best_of_family_xglm' due to the exclude_algos option or it is already trained.
# 19:33:00.476: Skipping StackedEnsemble 'all_xglm' due to the exclude_algos option or it is already trained.
# 19:33:00.478: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {GBM : [def_5 (1g, 10w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}]
# 19:33:00.483: AutoML build stopped: 2025.04.21 19:33:00.478
# 19:33:00.483: AutoML build done: built 20 models
# 19:33:00.485: AutoML duration: 12 min 25.402 sec
# 19:33:00.522: Verifying training frame immutability. . .
# 19:33:00.522: Training frame was not mutated (as expected).

# %% [markdown]
# ### Check the Results of H2O AutoML

# %%
lb_DIC = aml_DIC.leaderboard
lb_DIC.head(rows=lb_DIC.nrows)
# Out:
# model_id                                                   auc    logloss     aucpr    mean_per_class_error      rmse        mse
# ----------------------------------------------------  --------  ---------  --------  ----------------------  --------  ---------
# XGBoost_grid_1_AutoML_1_20250421_192034_model_2       0.927267  0.0794427  0.289099                0.312588  0.145423  0.0211479
# GBM_grid_1_AutoML_1_20250421_192034_model_1           0.925709  0.0816363  0.266839                0.274278  0.147066  0.0216285
# GBM_grid_1_AutoML_1_20250421_192034_model_2           0.92409   0.0829687  0.266857                0.282539  0.14787   0.0218654
# GBM_1_AutoML_1_20250421_192034                        0.922109  0.0821158  0.253244                0.275591  0.147257  0.0216847
# XGBoost_grid_1_AutoML_1_20250421_192034_model_3       0.921641  0.0814537  0.270418                0.276948  0.147114  0.0216426
# GBM_2_AutoML_1_20250421_192034                        0.920818  0.0867704  0.258711                0.301347  0.149699  0.0224099
# XGBoost_grid_1_AutoML_1_20250421_192034_model_1       0.91796   0.0833839  0.275988                0.276215  0.147441  0.021739
# XGBoost_3_AutoML_1_20250421_192034                    0.917024  0.0844456  0.265842                0.266266  0.147965  0.0218937
# GBM_5_AutoML_1_20250421_192034                        0.916999  0.0950583  0.220422                0.285814  0.156123  0.0243745
# GBM_3_AutoML_1_20250421_192034                        0.916676  0.0889034  0.245189                0.292245  0.150384  0.0226154
# XGBoost_1_AutoML_1_20250421_192034                    0.916573  0.0850495  0.261152                0.303334  0.149125  0.0222381
# XGBoost_2_AutoML_1_20250421_192034                    0.909679  0.0891653  0.24796                 0.268439  0.150297  0.0225891
# GBM_4_AutoML_1_20250421_192034                        0.90966   0.0921025  0.234197                0.284072  0.151296  0.0228903
# XRT_1_AutoML_1_20250421_192034                        0.892419  0.0900957  0.201815                0.284263  0.149669  0.0224007
# DRF_1_AutoML_1_20250421_192034                        0.889636  0.0893776  0.19648                 0.309768  0.149707  0.0224121
# GLM_1_AutoML_1_20250421_192034                        0.877784  0.0922263  0.203228                0.332702  0.151512  0.0229559
# DeepLearning_grid_3_AutoML_1_20250421_192034_model_1  0.858702  0.0954427  0.183864                0.348817  0.151121  0.0228375
# DeepLearning_grid_2_AutoML_1_20250421_192034_model_1  0.856448  0.0996135  0.188277                0.356492  0.150948  0.0227852
# DeepLearning_grid_1_AutoML_1_20250421_192034_model_1  0.84244   0.117225   0.172789                0.343103  0.153862  0.0236734
# DeepLearning_1_AutoML_1_20250421_192034               0.824212  0.103973   0.161308                0.331217  0.15372   0.0236297
# [20 rows x 7 columns]

# %%
# Retrieve the model by specifying the model ID to be saved from the leaderboard
model_id = "XGBoost_grid_1_AutoML_1_20250421_192034_model_2"
best_model = h2o.get_model(model_id)

# Retrieve second and third models for comparison necessary
#second_model_id = "GBM_grid_1_AutoML_1_20250421_192034_model_1"
#second_model = h2o.get_model(second_model_id)
#third_model_id = "GBM_grid_1_AutoML_1_20250421_192034_model_2"
#third_model = h2o.get_model(third_model_id)

# %%
#save the model
model_path_full = h2o.save_model(model=best_model, path=os.path.join(output_dir, f'h2omodels/model1/h2omodel_24{date}_best'), force=True)

#second_model_path_full = h2o.save_model(model=second_model, path=os.path.join(output_dir, f'h2omodels/model1/h2omodel_24{date}_second'), force=True)
#third_model_path_full = h2o.save_model(model=third_model, path=os.path.join(output_dir, f'h2omodels/model1/h2omodel_24{date}_third'), force=True)

# %%
with open(f'{date}/model_path_best_latest_model1.txt', 'w') as f:
    f.write(f"best_model: {model_path_full}\n")
    #f.write(f"second_model: {second_model_path_full}\n")
    #f.write(f"third_model: {third_model_path_full}\n")

# %% [markdown]
# #### Run H2O AutoML for minimum model

# %%
aml_DIC_minimum, train_minimum, test_minimum = get_aml_model(f'{date}_train_df_model1.csv', f"{date}_test_df_model1.csv", vars_minimum, 710)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 18:35:21.319: Project: AutoML_1_20250421_183521
# 18:35:21.320: 5-fold cross-validation will be used.
# 18:35:21.333: Setting stopping tolerance adaptively based on the training frame: 0.006505725117543193
# 18:35:21.333: Build control seed: 710
# 18:35:21.335: training frame: Frame key: AutoML_1_20250421_183521_training_py_37_sid_9482    cols: 5    rows: 23627  chunks: 32    size: 222988  checksum: 1451434568359112392
# 18:35:21.335: validation frame: NULL
# 18:35:21.336: leaderboard frame: NULL
# 18:35:21.336: blending frame: NULL
# 18:35:21.336: response column: y
# 18:35:21.336: fold column: null
# 18:35:21.336: weights column: null
# 18:35:21.358: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (7g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (7g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (6g, 60w)]}, {StackedEnsemble : [monotonic (9g, 10w), best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 18:35:21.393: Disabling Algo: StackedEnsemble as requested by the user.
# 18:35:21.394: Defined work allocations: [Work{def_2, XGBoost, ModelBuild, group=1, weight=10}, Work{def_1, GLM, ModelBuild, group=1, weight=10}, Work{def_5, GBM, ModelBuild, group=1, weight=10}, Work{def_1, XGBoost, ModelBuild, group=2, weight=10}, Work{def_1, DRF, ModelBuild, group=2, weight=10}, Work{def_2, GBM, ModelBuild, group=2, weight=10}, Work{def_3, GBM, ModelBuild, group=2, weight=10}, Work{def_4, GBM, ModelBuild, group=2, weight=10}, Work{def_3, XGBoost, ModelBuild, group=3, weight=10}, Work{XRT, DRF, ModelBuild, group=3, weight=10}, Work{def_1, GBM, ModelBuild, group=3, weight=10}, Work{def_1, DeepLearning, ModelBuild, group=3, weight=10}, Work{grid_1, XGBoost, HyperparamSearch, group=4, weight=90}, Work{grid_1, GBM, HyperparamSearch, group=4, weight=60}, Work{grid_1, DeepLearning, HyperparamSearch, group=4, weight=30}, Work{grid_2, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{grid_3, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{resume_best_grids, virtual, Dynamic, group=6, weight=60}, Work{lr_search, XGBoost, Selection, group=7, weight=30}, Work{lr_annealing, GBM, Selection, group=7, weight=10}]
# 18:35:21.394: Actual work allocations: [Work{def_2, XGBoost, ModelBuild, group=1, weight=10}, Work{def_1, GLM, ModelBuild, group=1, weight=10}, Work{def_5, GBM, ModelBuild, group=1, weight=10}, Work{def_1, XGBoost, ModelBuild, group=2, weight=10}, Work{def_1, DRF, ModelBuild, group=2, weight=10}, Work{def_2, GBM, ModelBuild, group=2, weight=10}, Work{def_3, GBM, ModelBuild, group=2, weight=10}, Work{def_4, GBM, ModelBuild, group=2, weight=10}, Work{def_3, XGBoost, ModelBuild, group=3, weight=10}, Work{XRT, DRF, ModelBuild, group=3, weight=10}, Work{def_1, GBM, ModelBuild, group=3, weight=10}, Work{def_1, DeepLearning, ModelBuild, group=3, weight=10}, Work{grid_1, XGBoost, HyperparamSearch, group=4, weight=90}, Work{grid_1, GBM, HyperparamSearch, group=4, weight=60}, Work{grid_1, DeepLearning, HyperparamSearch, group=4, weight=30}, Work{grid_2, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{grid_3, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{resume_best_grids, virtual, Dynamic, group=6, weight=60}, Work{lr_search, XGBoost, Selection, group=7, weight=30}, Work{lr_annealing, GBM, Selection, group=7, weight=10}]
# 18:35:21.396: AutoML job created: 2025.04.21 18:35:21.275
# 18:35:21.404: AutoML build started: 2025.04.21 18:35:21.398
# 18:35:21.456: No time limitation for XGBoost_1_AutoML_1_20250421_183521
# 18:35:21.459: AutoML: starting XGBoost_1_AutoML_1_20250421_183521 model training
# 18:35:21.490: XGBoost_1_AutoML_1_20250421_183521 [XGBoost def_2] started
#
# ██
# 18:35:31.200: XGBoost_1_AutoML_1_20250421_183521 [XGBoost def_2] complete
# 18:35:31.205: Adding model XGBoost_1_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=10s
# 18:35:31.232: New leader: XGBoost_1_AutoML_1_20250421_183521, auc: 0.8541784511376838
# 18:35:31.236: No time limitation for GLM_1_AutoML_1_20250421_183521
# 18:35:31.236: AutoML: starting GLM_1_AutoML_1_20250421_183521 model training
# 18:35:31.236: GLM_1_AutoML_1_20250421_183521 [GLM def_1] started
#
#
# 18:35:35.171: GLM_1_AutoML_1_20250421_183521 [GLM def_1] complete
# 18:35:35.171: Adding model GLM_1_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=0s, total=4s
# 18:35:35.192: No time limitation for GBM_1_AutoML_1_20250421_183521
# 18:35:35.192: AutoML: starting GBM_1_AutoML_1_20250421_183521 model training
# 18:35:35.197: GBM_1_AutoML_1_20250421_183521 [GBM def_5] started
#
# ██
# 18:35:44.926: GBM_1_AutoML_1_20250421_183521 [GBM def_5] complete
# 18:35:44.927: Adding model GBM_1_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=2s, total=10s
# 18:35:44.935: New leader: GBM_1_AutoML_1_20250421_183521, auc: 0.8559809321264326
# 18:35:44.945: No time limitation for XGBoost_2_AutoML_1_20250421_183521
# 18:35:44.945: AutoML: starting XGBoost_2_AutoML_1_20250421_183521 model training
# 18:35:44.951: XGBoost_2_AutoML_1_20250421_183521 [XGBoost def_1] started
#
# █
# 18:35:48.560: XGBoost_2_AutoML_1_20250421_183521 [XGBoost def_1] complete
# 18:35:48.560: Adding model XGBoost_2_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=4s
# 18:35:48.578: No time limitation for DRF_1_AutoML_1_20250421_183521
# 18:35:48.578: AutoML: starting DRF_1_AutoML_1_20250421_183521 model training
# 18:35:48.579: DRF_1_AutoML_1_20250421_183521 [DRF def_1] started
#
# █
# 18:35:53.902: DRF_1_AutoML_1_20250421_183521 [DRF def_1] complete
# 18:35:53.903: Adding model DRF_1_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=5s
# 18:35:53.914: No time limitation for GBM_2_AutoML_1_20250421_183521
# 18:35:53.914: AutoML: starting GBM_2_AutoML_1_20250421_183521 model training
# 18:35:53.915: GBM_2_AutoML_1_20250421_183521 [GBM def_2] started
#
# █
# 18:35:57.676: GBM_2_AutoML_1_20250421_183521 [GBM def_2] complete
# 18:35:57.676: Adding model GBM_2_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=4s
# 18:35:57.688: No time limitation for GBM_3_AutoML_1_20250421_183521
# 18:35:57.688: AutoML: starting GBM_3_AutoML_1_20250421_183521 model training
# 18:35:57.689: GBM_3_AutoML_1_20250421_183521 [GBM def_3] started
#
# █
# 18:36:01.390: GBM_3_AutoML_1_20250421_183521 [GBM def_3] complete
# 18:36:01.391: Adding model GBM_3_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=4s
#
# █
# 18:36:01.408: No time limitation for GBM_4_AutoML_1_20250421_183521
# 18:36:01.408: AutoML: starting GBM_4_AutoML_1_20250421_183521 model training
# 18:36:01.409: GBM_4_AutoML_1_20250421_183521 [GBM def_4] started
#
# █
# 18:36:04.847: GBM_4_AutoML_1_20250421_183521 [GBM def_4] complete
# 18:36:04.847: Adding model GBM_4_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=0s, total=3s
# 18:36:04.862: No time limitation for XGBoost_3_AutoML_1_20250421_183521
# 18:36:04.862: AutoML: starting XGBoost_3_AutoML_1_20250421_183521 model training
# 18:36:04.863: XGBoost_3_AutoML_1_20250421_183521 [XGBoost def_3] started
#
# █
# 18:36:09.408: XGBoost_3_AutoML_1_20250421_183521 [XGBoost def_3] complete
# 18:36:09.408: Adding model XGBoost_3_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=5s
# 18:36:09.419: New leader: XGBoost_3_AutoML_1_20250421_183521, auc: 0.8559827839294833
# 18:36:09.424: No time limitation for XRT_1_AutoML_1_20250421_183521
# 18:36:09.424: AutoML: starting XRT_1_AutoML_1_20250421_183521 model training
# 18:36:09.425: XRT_1_AutoML_1_20250421_183521 [DRF XRT (Extremely Randomized Trees)] started
#
# ███
# 18:36:20.378: XRT_1_AutoML_1_20250421_183521 [DRF XRT (Extremely Randomized Trees)] complete
# 18:36:20.378: Adding model XRT_1_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=2s, total=11s
# 18:36:20.524: No time limitation for GBM_5_AutoML_1_20250421_183521
# 18:36:20.526: AutoML: starting GBM_5_AutoML_1_20250421_183521 model training
# 18:36:20.558: GBM_5_AutoML_1_20250421_183521 [GBM def_1] started
#
# █
# 18:36:25.895: GBM_5_AutoML_1_20250421_183521 [GBM def_1] complete
# 18:36:25.896: Adding model GBM_5_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=5s
# 18:36:25.950: New leader: GBM_5_AutoML_1_20250421_183521, auc: 0.8578418161344751
# 18:36:25.972: No time limitation for DeepLearning_1_AutoML_1_20250421_183521
# 18:36:25.972: AutoML: starting DeepLearning_1_AutoML_1_20250421_183521 model training
# 18:36:25.975: DeepLearning_1_AutoML_1_20250421_183521 [DeepLearning def_1] started
#
# █
# 18:36:31.604: DeepLearning_1_AutoML_1_20250421_183521 [DeepLearning def_1] complete
# 18:36:31.605: Adding model DeepLearning_1_AutoML_1_20250421_183521 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=6s
# 18:36:31.745: No time limitation for XGBoost_grid_1_AutoML_1_20250421_183521
# 18:36:31.746: AutoML: starting XGBoost_grid_1_AutoML_1_20250421_183521 hyperparameter search
# 18:36:31.801: XGBoost_grid_1_AutoML_1_20250421_183521 [XGBoost Grid Search] started
#
# ██
# 18:36:36.832: Built: 1 models for HyperparamSearch : XGBoost_grid_1_AutoML_1_20250421_183521 [XGBoost Grid Search]
# 18:36:36.844: Adding model XGBoost_grid_1_AutoML_1_20250421_183521_model_1 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=4s
# 18:36:41.922: Built: 2 models for HyperparamSearch : XGBoost_grid_1_AutoML_1_20250421_183521 [XGBoost Grid Search]
# 18:36:41.940: Adding model XGBoost_grid_1_AutoML_1_20250421_183521_model_2 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=5s
# 18:36:47.140: XGBoost_grid_1_AutoML_1_20250421_183521 [XGBoost Grid Search] complete
# 18:36:47.140: Built: 3 models for HyperparamSearch : XGBoost_grid_1_AutoML_1_20250421_183521 [XGBoost Grid Search]
# 18:36:47.140: Adding model XGBoost_grid_1_AutoML_1_20250421_183521_model_3 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=6s
# 18:36:47.164: No time limitation for GBM_grid_1_AutoML_1_20250421_183521
# 18:36:47.165: AutoML: starting GBM_grid_1_AutoML_1_20250421_183521 hyperparameter search
# 18:36:47.169: GBM_grid_1_AutoML_1_20250421_183521 [GBM Grid Search] started
#
# █████████████████
# 18:36:54.241: Built: 1 models for HyperparamSearch : GBM_grid_1_AutoML_1_20250421_183521 [GBM Grid Search]
# 18:36:54.244: Adding model GBM_grid_1_AutoML_1_20250421_183521_model_1 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=7s
# 18:37:02.166: GBM_grid_1_AutoML_1_20250421_183521 [GBM Grid Search] complete
# 18:37:02.166: Built: 2 models for HyperparamSearch : GBM_grid_1_AutoML_1_20250421_183521 [GBM Grid Search]
# 18:37:02.167: Adding model GBM_grid_1_AutoML_1_20250421_183521_model_2 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=1s, total=8s
# 18:37:02.187: No time limitation for DeepLearning_grid_1_AutoML_1_20250421_183521
# 18:37:02.187: AutoML: starting DeepLearning_grid_1_AutoML_1_20250421_183521 hyperparameter search
# 18:37:02.193: DeepLearning_grid_1_AutoML_1_20250421_183521 [DeepLearning Grid Search] started
#
# █████████████████
# 18:40:09.970: DeepLearning_grid_1_AutoML_1_20250421_183521 [DeepLearning Grid Search] complete
# 18:40:09.970: Built: 1 models for HyperparamSearch : DeepLearning_grid_1_AutoML_1_20250421_183521 [DeepLearning Grid Search]
# 18:40:09.973: Adding model DeepLearning_grid_1_AutoML_1_20250421_183521_model_1 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=45s, total=188s
# 18:40:10.11: No time limitation for DeepLearning_grid_2_AutoML_1_20250421_183521
# 18:40:10.11: AutoML: starting DeepLearning_grid_2_AutoML_1_20250421_183521 hyperparameter search
# 18:40:10.13: DeepLearning_grid_2_AutoML_1_20250421_183521 [DeepLearning Grid Search] started
#
# ██████
# 18:43:08.135: DeepLearning_grid_2_AutoML_1_20250421_183521 [DeepLearning Grid Search] complete
# 18:43:08.135: Built: 1 models for HyperparamSearch : DeepLearning_grid_2_AutoML_1_20250421_183521 [DeepLearning Grid Search]
# 18:43:08.136: Adding model DeepLearning_grid_2_AutoML_1_20250421_183521_model_1 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=33s, total=178s
# 18:43:08.159: No time limitation for DeepLearning_grid_3_AutoML_1_20250421_183521
# 18:43:08.159: AutoML: starting DeepLearning_grid_3_AutoML_1_20250421_183521 hyperparameter search
# 18:43:08.161: DeepLearning_grid_3_AutoML_1_20250421_183521 [DeepLearning Grid Search] started
#
# █████| (done) 100%
#
# 18:48:23.811: DeepLearning_grid_3_AutoML_1_20250421_183521 [DeepLearning Grid Search] complete
# 18:48:23.811: Built: 1 models for HyperparamSearch : DeepLearning_grid_3_AutoML_1_20250421_183521 [DeepLearning Grid Search]
# 18:48:23.812: Adding model DeepLearning_grid_3_AutoML_1_20250421_183521_model_1 to leaderboard Leaderboard_AutoML_1_20250421_183521@@y. Training time: model=46s, total=316s
# 18:48:23.829: AutoML: hit the max_models limit; skipping completion resume_best_grids
# 18:48:23.829: AutoML: hit the max_models limit; skipping XGBoost lr_search
# 18:48:23.829: AutoML: hit the max_models limit; skipping GBM lr_annealing
# 18:48:23.847: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option or it is already trained.
# 18:48:23.848: Skipping StackedEnsemble 'best_of_family_xglm' due to the exclude_algos option or it is already trained.
# 18:48:23.853: Skipping StackedEnsemble 'all_xglm' due to the exclude_algos option or it is already trained.
# 18:48:23.855: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {GBM : [def_5 (1g, 10w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}]
# 18:48:23.857: AutoML build stopped: 2025.04.21 18:48:23.855
# 18:48:23.857: AutoML build done: built 20 models
# 18:48:23.857: AutoML duration: 13 min  2.457 sec
# 18:48:23.872: Verifying training frame immutability. . .
# 18:48:23.873: Training frame was not mutated (as expected).

# %%
lb_DIC_minimum = aml_DIC_minimum.leaderboard
lb_DIC_minimum.head(rows=lb_DIC_minimum.nrows)
# Out:
# model_id                                                   auc    logloss      aucpr    mean_per_class_error      rmse        mse
# ----------------------------------------------------  --------  ---------  ---------  ----------------------  --------  ---------
# GBM_5_AutoML_1_20250421_183521                        0.857842  0.0977169  0.154221                 0.345948  0.154942  0.0240071
# XGBoost_3_AutoML_1_20250421_183521                    0.855983  0.0961244  0.160881                 0.376658  0.153003  0.0234098
# GBM_1_AutoML_1_20250421_183521                        0.855981  0.0949462  0.16362                  0.360255  0.151984  0.0230992
# GBM_2_AutoML_1_20250421_183521                        0.855136  0.0970462  0.150052                 0.341954  0.153981  0.02371
# XGBoost_1_AutoML_1_20250421_183521                    0.854178  0.0961085  0.16171                  0.365591  0.15277   0.0233387
# XGBoost_grid_1_AutoML_1_20250421_183521_model_1       0.85399   0.0965982  0.156171                 0.361841  0.153375  0.0235239
# GBM_3_AutoML_1_20250421_183521                        0.850588  0.0981584  0.145308                 0.351008  0.154159  0.023765
# XGBoost_grid_1_AutoML_1_20250421_183521_model_2       0.847869  0.0984636  0.147791                 0.360278  0.154196  0.0237763
# XGBoost_2_AutoML_1_20250421_183521                    0.845031  0.0992152  0.145592                 0.369879  0.154554  0.0238868
# XGBoost_grid_1_AutoML_1_20250421_183521_model_3       0.844786  0.0994074  0.150835                 0.377484  0.154408  0.0238417
# GBM_4_AutoML_1_20250421_183521                        0.843971  0.0996938  0.141276                 0.34321   0.154701  0.0239325
# GBM_grid_1_AutoML_1_20250421_183521_model_1           0.831245  0.0997131  0.139609                 0.380247  0.153833  0.0236646
# GBM_grid_1_AutoML_1_20250421_183521_model_2           0.826101  0.0998153  0.13796                  0.362255  0.153593  0.0235907
# XRT_1_AutoML_1_20250421_183521                        0.818067  0.162558   0.142428                 0.343582  0.15513   0.0240654
# DRF_1_AutoML_1_20250421_183521                        0.817928  0.169828   0.147533                 0.354991  0.15481   0.0239662
# DeepLearning_1_AutoML_1_20250421_183521               0.813466  0.104092   0.115477                 0.346371  0.155072  0.0240473
# GLM_1_AutoML_1_20250421_183521                        0.783305  0.107626   0.102283                 0.35008   0.156514  0.0244967
# DeepLearning_grid_2_AutoML_1_20250421_183521_model_1  0.754396  0.16762    0.0895155                0.407933  0.159075  0.0253049
# DeepLearning_grid_3_AutoML_1_20250421_183521_model_1  0.705301  0.159182   0.0743831                0.438171  0.160181  0.0256581
# DeepLearning_grid_1_AutoML_1_20250421_183521_model_1  0.646546  0.180031   0.0540867                0.441059  0.159398  0.0254076
# [20 rows x 7 columns]

# %%
# Retrieve the model by specifying the model ID to be saved from the leaderboard
model_id = "GBM_5_AutoML_1_20250421_183521"
best_model = h2o.get_model(model_id)

# Retrieve second and third models for comparison necessary
#second_model_id = "XGBoost_3_AutoML_1_20250421_183521"
#second_model = h2o.get_model(second_model_id)
#third_model_id = "GBM_1_AutoML_1_20250421_183521"
#third_model = h2o.get_model(third_model_id)

# %%
#save the model
model_path_full = h2o.save_model(model=best_model, path=os.path.join(output_dir, f'h2omodels/model1_minimum/h2omodel_24{date}_best'), force=True)
#second_model_path_full = h2o.save_model(model=second_model, path=os.path.join(output_dir, f'h2omodels/model1_minimum/h2omodel_24{date}_second'), force=True)
#third_model_path_full = h2o.save_model(model=third_model, path=os.path.join(output_dir, f'h2omodels/model1_minimum/h2omodel_24{date}_third'), force=True)

# %%
with open(f'{date}/model_path_best_latest_model1_minimum.txt', 'w') as f:
    f.write(f"best_model: {model_path_full}\n")
    #f.write(f"second_model: {second_model_path_full}\n")
    #f.write(f"third_model: {third_model_path_full}\n")

# %% [markdown]
# #### Run H2O AutoML for Compact Model

# %%
aml_DIC_compact, train_compact, test_compact = get_aml_model(f'{date}_train_df_model1.csv', f"{date}_test_df_model1.csv", vars_compact, 710)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 18:48:37.138: Project: AutoML_1_20250421_184837
# 18:48:37.139: 5-fold cross-validation will be used.
# 18:48:37.151: Setting stopping tolerance adaptively based on the training frame: 0.006505725117543193
# 18:48:37.151: Build control seed: 710
# 18:48:37.155: training frame: Frame key: AutoML_1_20250421_184837_training_py_42_sid_bcfd    cols: 25    rows: 23627  chunks: 32    size: 766581  checksum: 8457199322190453172
# 18:48:37.155: validation frame: NULL
# 18:48:37.155: leaderboard frame: NULL
# 18:48:37.155: blending frame: NULL
# 18:48:37.155: response column: y
# 18:48:37.155: fold column: null
# 18:48:37.155: weights column: null
# 18:48:37.172: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (7g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (7g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (6g, 60w)]}, {StackedEnsemble : [monotonic (9g, 10w), best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 18:48:37.193: Disabling Algo: StackedEnsemble as requested by the user.
# 18:48:37.193: Defined work allocations: [Work{def_2, XGBoost, ModelBuild, group=1, weight=10}, Work{def_1, GLM, ModelBuild, group=1, weight=10}, Work{def_5, GBM, ModelBuild, group=1, weight=10}, Work{def_1, XGBoost, ModelBuild, group=2, weight=10}, Work{def_1, DRF, ModelBuild, group=2, weight=10}, Work{def_2, GBM, ModelBuild, group=2, weight=10}, Work{def_3, GBM, ModelBuild, group=2, weight=10}, Work{def_4, GBM, ModelBuild, group=2, weight=10}, Work{def_3, XGBoost, ModelBuild, group=3, weight=10}, Work{XRT, DRF, ModelBuild, group=3, weight=10}, Work{def_1, GBM, ModelBuild, group=3, weight=10}, Work{def_1, DeepLearning, ModelBuild, group=3, weight=10}, Work{grid_1, XGBoost, HyperparamSearch, group=4, weight=90}, Work{grid_1, GBM, HyperparamSearch, group=4, weight=60}, Work{grid_1, DeepLearning, HyperparamSearch, group=4, weight=30}, Work{grid_2, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{grid_3, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{resume_best_grids, virtual, Dynamic, group=6, weight=60}, Work{lr_search, XGBoost, Selection, group=7, weight=30}, Work{lr_annealing, GBM, Selection, group=7, weight=10}]
# 18:48:37.193: Actual work allocations: [Work{def_2, XGBoost, ModelBuild, group=1, weight=10}, Work{def_1, GLM, ModelBuild, group=1, weight=10}, Work{def_5, GBM, ModelBuild, group=1, weight=10}, Work{def_1, XGBoost, ModelBuild, group=2, weight=10}, Work{def_1, DRF, ModelBuild, group=2, weight=10}, Work{def_2, GBM, ModelBuild, group=2, weight=10}, Work{def_3, GBM, ModelBuild, group=2, weight=10}, Work{def_4, GBM, ModelBuild, group=2, weight=10}, Work{def_3, XGBoost, ModelBuild, group=3, weight=10}, Work{XRT, DRF, ModelBuild, group=3, weight=10}, Work{def_1, GBM, ModelBuild, group=3, weight=10}, Work{def_1, DeepLearning, ModelBuild, group=3, weight=10}, Work{grid_1, XGBoost, HyperparamSearch, group=4, weight=90}, Work{grid_1, GBM, HyperparamSearch, group=4, weight=60}, Work{grid_1, DeepLearning, HyperparamSearch, group=4, weight=30}, Work{grid_2, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{grid_3, DeepLearning, HyperparamSearch, group=5, weight=30}, Work{resume_best_grids, virtual, Dynamic, group=6, weight=60}, Work{lr_search, XGBoost, Selection, group=7, weight=30}, Work{lr_annealing, GBM, Selection, group=7, weight=10}]
# 18:48:37.194: AutoML job created: 2025.04.21 18:48:37.102
# 18:48:37.200: AutoML build started: 2025.04.21 18:48:37.195
# 18:48:37.226: No time limitation for XGBoost_1_AutoML_1_20250421_184837
# 18:48:37.227: AutoML: starting XGBoost_1_AutoML_1_20250421_184837 model training
# 18:48:37.233: XGBoost_1_AutoML_1_20250421_184837 [XGBoost def_2] started
#
# ██
# 18:48:48.214: XGBoost_1_AutoML_1_20250421_184837 [XGBoost def_2] complete
#
#
# 18:48:48.257: Adding model XGBoost_1_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=2s, total=11s
# 18:48:48.301: New leader: XGBoost_1_AutoML_1_20250421_184837, auc: 0.8935361390048838
# 18:48:48.308: No time limitation for GLM_1_AutoML_1_20250421_184837
# 18:48:48.308: AutoML: starting GLM_1_AutoML_1_20250421_184837 model training
# 18:48:48.308: GLM_1_AutoML_1_20250421_184837 [GLM def_1] started
#
#
# 18:48:54.978: GLM_1_AutoML_1_20250421_184837 [GLM def_1] complete
# 18:48:54.978: Adding model GLM_1_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=1s, total=7s
# 18:48:55.10: No time limitation for GBM_1_AutoML_1_20250421_184837
# 18:48:55.12: AutoML: starting GBM_1_AutoML_1_20250421_184837 model training
# 18:48:55.20: GBM_1_AutoML_1_20250421_184837 [GBM def_5] started
#
# ██
# 18:49:09.108: GBM_1_AutoML_1_20250421_184837 [GBM def_5] complete
# 18:49:09.108: Adding model GBM_1_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=2s, total=14s
# 18:49:09.116: New leader: GBM_1_AutoML_1_20250421_184837, auc: 0.8984840143101642
#
# █
# 18:49:09.126: No time limitation for XGBoost_2_AutoML_1_20250421_184837
# 18:49:09.127: AutoML: starting XGBoost_2_AutoML_1_20250421_184837 model training
# 18:49:09.129: XGBoost_2_AutoML_1_20250421_184837 [XGBoost def_1] started
#
#
# 18:49:16.670: XGBoost_2_AutoML_1_20250421_184837 [XGBoost def_1] complete
# 18:49:16.671: Adding model XGBoost_2_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=2s, total=8s
# 18:49:16.717: No time limitation for DRF_1_AutoML_1_20250421_184837
# 18:49:16.718: AutoML: starting DRF_1_AutoML_1_20250421_184837 model training
# 18:49:16.719: DRF_1_AutoML_1_20250421_184837 [DRF def_1] started
#
# ██
# 18:49:28.118: DRF_1_AutoML_1_20250421_184837 [DRF def_1] complete
# 18:49:28.119: Adding model DRF_1_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=2s, total=11s
# 18:49:28.135: No time limitation for GBM_2_AutoML_1_20250421_184837
# 18:49:28.135: AutoML: starting GBM_2_AutoML_1_20250421_184837 model training
# 18:49:28.137: GBM_2_AutoML_1_20250421_184837 [GBM def_2] started
#
# █
# 18:49:37.728: GBM_2_AutoML_1_20250421_184837 [GBM def_2] complete
# 18:49:37.729: Adding model GBM_2_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=1s, total=10s
# 18:49:37.747: No time limitation for GBM_3_AutoML_1_20250421_184837
# 18:49:37.748: AutoML: starting GBM_3_AutoML_1_20250421_184837 model training
# 18:49:37.749: GBM_3_AutoML_1_20250421_184837 [GBM def_3] started
#
# ██
# 18:49:45.559: GBM_3_AutoML_1_20250421_184837 [GBM def_3] complete
# 18:49:45.559: Adding model GBM_3_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=1s, total=8s
# 18:49:45.578: No time limitation for GBM_4_AutoML_1_20250421_184837
# 18:49:45.578: AutoML: starting GBM_4_AutoML_1_20250421_184837 model training
# 18:49:45.580: GBM_4_AutoML_1_20250421_184837 [GBM def_4] started
#
# █
# 18:49:53.702: GBM_4_AutoML_1_20250421_184837 [GBM def_4] complete
# 18:49:53.702: Adding model GBM_4_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=1s, total=8s
# 18:49:53.715: No time limitation for XGBoost_3_AutoML_1_20250421_184837
# 18:49:53.716: AutoML: starting XGBoost_3_AutoML_1_20250421_184837 model training
# 18:49:53.719: XGBoost_3_AutoML_1_20250421_184837 [XGBoost def_3] started
#
# █
# 18:50:00.181: XGBoost_3_AutoML_1_20250421_184837 [XGBoost def_3] complete
# 18:50:00.181: Adding model XGBoost_3_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=1s, total=6s
# 18:50:00.195: No time limitation for XRT_1_AutoML_1_20250421_184837
# 18:50:00.195: AutoML: starting XRT_1_AutoML_1_20250421_184837 model training
# 18:50:00.196: XRT_1_AutoML_1_20250421_184837 [DRF XRT (Extremely Randomized Trees)] started
#
# ██
# 18:50:13.616: XRT_1_AutoML_1_20250421_184837 [DRF XRT (Extremely Randomized Trees)] complete
# 18:50:13.621: Adding model XRT_1_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=2s, total=13s
# 18:50:13.649: No time limitation for GBM_5_AutoML_1_20250421_184837
# 18:50:13.650: AutoML: starting GBM_5_AutoML_1_20250421_184837 model training
# 18:50:13.656: GBM_5_AutoML_1_20250421_184837 [GBM def_1] started
#
# █
# 18:50:22.320: GBM_5_AutoML_1_20250421_184837 [GBM def_1] complete
# 18:50:22.321: Adding model GBM_5_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=1s, total=9s
# 18:50:22.366: No time limitation for DeepLearning_1_AutoML_1_20250421_184837
# 18:50:22.366: AutoML: starting DeepLearning_1_AutoML_1_20250421_184837 model training
# 18:50:22.369: DeepLearning_1_AutoML_1_20250421_184837 [DeepLearning def_1] started
#
# █
# 18:50:27.970: DeepLearning_1_AutoML_1_20250421_184837 [DeepLearning def_1] complete
# 18:50:27.970: Adding model DeepLearning_1_AutoML_1_20250421_184837 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=1s, total=6s
# 18:50:28.3: No time limitation for XGBoost_grid_1_AutoML_1_20250421_184837
# 18:50:28.3: AutoML: starting XGBoost_grid_1_AutoML_1_20250421_184837 hyperparameter search
# 18:50:28.57: XGBoost_grid_1_AutoML_1_20250421_184837 [XGBoost Grid Search] started
#
# ████
# 18:50:36.104: Built: 1 models for HyperparamSearch : XGBoost_grid_1_AutoML_1_20250421_184837 [XGBoost Grid Search]
# 18:50:36.104: Adding model XGBoost_grid_1_AutoML_1_20250421_184837_model_1 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=2s, total=8s
# 18:50:49.247: Built: 2 models for HyperparamSearch : XGBoost_grid_1_AutoML_1_20250421_184837 [XGBoost Grid Search]
# 18:50:49.248: Adding model XGBoost_grid_1_AutoML_1_20250421_184837_model_2 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=3s, total=13s
# 18:51:00.514: XGBoost_grid_1_AutoML_1_20250421_184837 [XGBoost Grid Search] complete
# 18:51:00.514: Built: 3 models for HyperparamSearch : XGBoost_grid_1_AutoML_1_20250421_184837 [XGBoost Grid Search]
# 18:51:00.515: Adding model XGBoost_grid_1_AutoML_1_20250421_184837_model_3 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=3s, total=11s
# 18:51:00.532: No time limitation for GBM_grid_1_AutoML_1_20250421_184837
# 18:51:00.532: AutoML: starting GBM_grid_1_AutoML_1_20250421_184837 hyperparameter search
# 18:51:00.535: GBM_grid_1_AutoML_1_20250421_184837 [GBM Grid Search] started
#
# ████████████████
# 18:51:09.577: Built: 1 models for HyperparamSearch : GBM_grid_1_AutoML_1_20250421_184837 [GBM Grid Search]
# 18:51:09.578: Adding model GBM_grid_1_AutoML_1_20250421_184837_model_1 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=1s, total=8s
# 18:51:16.387: GBM_grid_1_AutoML_1_20250421_184837 [GBM Grid Search] complete
# 18:51:16.387: Built: 2 models for HyperparamSearch : GBM_grid_1_AutoML_1_20250421_184837 [GBM Grid Search]
# 18:51:16.388: Adding model GBM_grid_1_AutoML_1_20250421_184837_model_2 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=1s, total=7s
# 18:51:16.407: No time limitation for DeepLearning_grid_1_AutoML_1_20250421_184837
# 18:51:16.407: AutoML: starting DeepLearning_grid_1_AutoML_1_20250421_184837 hyperparameter search
# 18:51:16.413: DeepLearning_grid_1_AutoML_1_20250421_184837 [DeepLearning Grid Search] started
#
# ██████████████████
# 18:54:58.647: DeepLearning_grid_1_AutoML_1_20250421_184837 [DeepLearning Grid Search] complete
# 18:54:58.647: Built: 1 models for HyperparamSearch : DeepLearning_grid_1_AutoML_1_20250421_184837 [DeepLearning Grid Search]
# 18:54:58.650: Adding model DeepLearning_grid_1_AutoML_1_20250421_184837_model_1 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=53s, total=222s
# 18:54:58.676: No time limitation for DeepLearning_grid_2_AutoML_1_20250421_184837
# 18:54:58.676: AutoML: starting DeepLearning_grid_2_AutoML_1_20250421_184837 hyperparameter search
# 18:54:58.678: DeepLearning_grid_2_AutoML_1_20250421_184837 [DeepLearning Grid Search] started
#
# ███████
# 19:03:31.105: DeepLearning_grid_2_AutoML_1_20250421_184837 [DeepLearning Grid Search] complete
# 19:03:31.105: Built: 1 models for HyperparamSearch : DeepLearning_grid_2_AutoML_1_20250421_184837 [DeepLearning Grid Search]
# 19:03:31.108: Adding model DeepLearning_grid_2_AutoML_1_20250421_184837_model_1 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=129s, total=512s
# 19:03:31.160: No time limitation for DeepLearning_grid_3_AutoML_1_20250421_184837
# 19:03:31.161: AutoML: starting DeepLearning_grid_3_AutoML_1_20250421_184837 hyperparameter search
# 19:03:31.169: DeepLearning_grid_3_AutoML_1_20250421_184837 [DeepLearning Grid Search] started
#
# ██| (done) 100%
#
# 19:10:47.713: DeepLearning_grid_3_AutoML_1_20250421_184837 [DeepLearning Grid Search] complete
# 19:10:47.713: Built: 1 models for HyperparamSearch : DeepLearning_grid_3_AutoML_1_20250421_184837 [DeepLearning Grid Search]
# 19:10:47.714: Adding model DeepLearning_grid_3_AutoML_1_20250421_184837_model_1 to leaderboard Leaderboard_AutoML_1_20250421_184837@@y. Training time: model=96s, total=437s
# 19:10:47.726: AutoML: hit the max_models limit; skipping completion resume_best_grids
# 19:10:47.726: AutoML: hit the max_models limit; skipping XGBoost lr_search
# 19:10:47.726: AutoML: hit the max_models limit; skipping GBM lr_annealing
# 19:10:47.746: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option or it is already trained.
# 19:10:47.748: Skipping StackedEnsemble 'best_of_family_xglm' due to the exclude_algos option or it is already trained.
# 19:10:47.751: Skipping StackedEnsemble 'all_xglm' due to the exclude_algos option or it is already trained.
# 19:10:47.752: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {GBM : [def_5 (1g, 10w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}]
# 19:10:47.760: AutoML build stopped: 2025.04.21 19:10:47.752
# 19:10:47.761: AutoML build done: built 20 models
# 19:10:47.761: AutoML duration: 22 min 10.557 sec
# 19:10:47.786: Verifying training frame immutability. . .
# 19:10:47.786: Training frame was not mutated (as expected).

# %%
lb_DIC_compact = aml_DIC_compact.leaderboard
lb_DIC_compact.head(rows=lb_DIC_compact.nrows)
# Out:
# model_id                                                   auc    logloss      aucpr    mean_per_class_error      rmse        mse
# ----------------------------------------------------  --------  ---------  ---------  ----------------------  --------  ---------
# GBM_1_AutoML_1_20250421_184837                        0.898484  0.0870794  0.225512                 0.347443  0.148932  0.0221808
# XGBoost_grid_1_AutoML_1_20250421_184837_model_2       0.898229  0.0896516  0.226978                 0.296713  0.15022   0.0225662
# GBM_5_AutoML_1_20250421_184837                        0.895577  0.0949914  0.203553                 0.308611  0.154522  0.0238771
# XGBoost_grid_1_AutoML_1_20250421_184837_model_1       0.895514  0.088589   0.227149                 0.333352  0.150123  0.0225368
# GBM_grid_1_AutoML_1_20250421_184837_model_2           0.894664  0.0876524  0.231902                 0.302326  0.148605  0.0220833
# XGBoost_1_AutoML_1_20250421_184837                    0.893536  0.0896118  0.217453                 0.324428  0.150718  0.022716
# GBM_2_AutoML_1_20250421_184837                        0.893499  0.0904963  0.227381                 0.306049  0.150755  0.0227269
# XGBoost_3_AutoML_1_20250421_184837                    0.891178  0.0884784  0.241161                 0.31888   0.148666  0.0221016
# GBM_3_AutoML_1_20250421_184837                        0.890716  0.0923608  0.206473                 0.29932   0.151978  0.0230975
# XGBoost_2_AutoML_1_20250421_184837                    0.886831  0.0925466  0.219491                 0.310191  0.151194  0.0228598
# GBM_4_AutoML_1_20250421_184837                        0.886703  0.0945861  0.202123                 0.348703  0.152662  0.0233058
# XRT_1_AutoML_1_20250421_184837                        0.880104  0.0962752  0.192585                 0.313144  0.15016   0.0225479
# GBM_grid_1_AutoML_1_20250421_184837_model_1           0.878664  0.094202   0.201809                 0.352361  0.15176   0.0230312
# XGBoost_grid_1_AutoML_1_20250421_184837_model_3       0.878255  0.0974144  0.200012                 0.318801  0.153281  0.0234951
# DRF_1_AutoML_1_20250421_184837                        0.877936  0.11355    0.197389                 0.287149  0.149687  0.0224063
# GLM_1_AutoML_1_20250421_184837                        0.834055  0.100223   0.135968                 0.332918  0.154544  0.0238839
# DeepLearning_1_AutoML_1_20250421_184837               0.803872  0.104884   0.113783                 0.386977  0.15585   0.0242894
# DeepLearning_grid_2_AutoML_1_20250421_184837_model_1  0.753435  0.141631   0.0965996                0.41456   0.162168  0.0262984
# DeepLearning_grid_3_AutoML_1_20250421_184837_model_1  0.752408  0.124856   0.0921889                0.394158  0.161983  0.0262383
# DeepLearning_grid_1_AutoML_1_20250421_184837_model_1  0.735775  0.176529   0.0942875                0.381691  0.159462  0.0254281
# [20 rows x 7 columns]

# %%
# Retrieve the model by specifying the model ID to be saved from the leaderboard
model_id = "GBM_1_AutoML_1_20250421_184837"
best_model = h2o.get_model(model_id)

# Retrieve second and third models for comparison necessary
#second_model_id = "XGBoost_grid_1_AutoML_1_20250421_184837_model_2"
#second_model = h2o.get_model(second_model_id)
#third_model_id = "GBM_5_AutoML_1_20250421_184837"
#third_model = h2o.get_model(third_model_id)

# %%
#save the model
model_path_full = h2o.save_model(model=best_model, path=os.path.join(output_dir, f'h2omodels/model1_compact/h2omodel_24{date}_best'), force=True)
#second_model_path_full = h2o.save_model(model=second_model, path=os.path.join(output_dir, f'h2omodels/model1_compact/h2omodel_24{date}_second'), force=True)
#third_model_path_full = h2o.save_model(model=third_model, path=os.path.join(output_dir, f'h2omodels/model1_compact/h2omodel_24{date}_third'), force=True)

# %%
with open(f'{date}/model_path_best_latest_model1_compact.txt', 'w') as f:
    f.write(f"best_model: {model_path_full}\n")
    #f.write(f"second_model: {second_model_path_full}\n")
    #f.write(f"third_model: {third_model_path_full}\n")
